# %% [markdown]
# # !pip install PyPDF2
# # !pip install nltk
# # !pip install summarizer
# # !pip install bert-extractive-summarizer
# # !pip install transformers
# # nltk.download('punkt')

# %%
from summarizer import BertSummarizer
import PyPDF2
from PyPDF2 import PdfReader
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 from summarizer import BertSummarizer
#       2 import PyPDF2
#       3 from PyPDF2 import PdfReader
#
# ImportError: cannot import name 'BertSummarizer' from 'summarizer' (C:\Users\Sudhir Kulaye\AppData\Roaming\Python\Python311\site-packages\summarizer\__init__.py)

# %%
# Function to extract text from PDF
def extract_text_from_pdf(pdf_path):
    text = ''
    with open(pdf_path, 'rb') as file:
        reader = PdfReader(file)
        for page in reader.pages:
            text += page.extract_text()
    return text

# %%
# Function to generate bulleted summary
# def generate_summary(text):
#     sentences = sent_tokenize(text)
#     word_counts = Counter(sentences)
#     sorted_sentences = sorted(sentences, key=lambda x: word_counts[x], reverse=True)
#     summary = sorted_sentences[:5]  # Select top 5 sentences as summary
#     return summary

# Function to generate plain text summary
def generate_summary(text):
    sentences = sent_tokenize(text)
    word_counts = Counter(sentences)
    sorted_sentences = sorted(sentences, key=lambda x: word_counts[x], reverse=True)
    summary = ' '.join(sorted_sentences[:5])  # Concatenate top 5 sentences into a single paragraph
    return summary

# %%
# Path to the PDF file
pdf_path = "C:/MyDocuments/03Business/05ResearchAndAnalysis/StockInvestments/ResearchReports/Sector/BFSI/20240507_Banks_AMBIT.pdf"

# Extract text from PDF
#pdf_text = extract_text_from_pdf(pdf_path)

#print(pdf_text)
pdf_text = "SFBs - Counting chickens before they hatch? Conversion to universal bank is unlikely to change business economics for SFBs. Vintage, branch network and transactional/corporate banking capabilities would drive lower cost of funds than a universal license. Increased leverage capabilities are unlikely as SFBs’ leverage of ~8x now is similar to universal private banks. Fee income can improve marginally as lower PSL targets after universal license can free up some PSL assets to generate fee, but would be short-lived. SFBs’ performance has been below expectations as decrease in cost of funds hasn’t sufficed to offset regulatory cost of banking license and higher operating expenses. Also, most SFBs still have disproportionate exposure to microfinance loans. We believe SFBs have a long way before they drive 15% sustainable ROE which involves asset diversification, lower cost of funds and lower cost-to-income ratio; and role of universal banking license would be limited in the initial part of this journey. Roadmap for universal banking Last week, RBI issued roadmap for small finance banks (SFBs) to voluntarily transition to universal banks. RBI came up with the concept of SFB in 2015 to increase financial inclusion in the country and issued SFB license to 11 entities. The idea behind these specialized licenses was to increase banking penetration at the bottom of the pyramid. Hence there were some differences on regulations for SFBs vs universal banks with respect to customer profile, capital requirement and share of priority sector loans etc."

# Create Summarizer object
summarizer = Summarizer()

# Generate summary
summary = summarizer(pdf_text, ratio=0.1)  # Adjust the ratio as needed

# Print summary
print("Summary:")
print(summary)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 14
#      11 summarizer = Summarizer()
#      13 # Generate summary
# ---> 14 summary = summarizer(pdf_text, ratio=0.1)  # Adjust the ratio as needed
#      16 # Print summary
#      17 print("Summary:")
#
# TypeError: 'Summarizer' object is not callable

# %%
# !pip install transformers
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
